# %% [markdown]
# This notebook add economic features and imputates data

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('final_tuik.csv')

# Find columns with all empty values
empty_columns = df.columns[df.isnull().all()]

# Print the empty columns
print("Columns with all empty values:", empty_columns.tolist())
# Out:
# Columns with all empty values: ['tuitionFee', 'universityFoundingYear', 'facultyFoundingYear', 'revenue', 'tuitionFeeIncrease']

# %%
# Define the data for base salary, inflation, and growth by year
base_salary_by_year = {
    2019: 2103,
    2020: 2103,   
    2021: 2825,
    2022: 5500,
    2023: 11402,
    2024: 17002
}

inflation_by_year = {
    2019: 11.8,
    2020: 14,
    2021: 36,
    2022: 64,
    2023: 64,
    2024: 64
}

growth_by_year = {
    2019: 0.7,
    2020: 1.8,    
    2021: 11.6,
    2022: 5.4,
    2023: 3.8,
    2024: 2.7
}

# Open the CSV file
df = pd.read_csv('final_tuik.csv')

# Add the new columns based on the academic year
df['base_salary_by_year'] = df['academicYear'].map(base_salary_by_year)
df['inflation_by_year'] = df['academicYear'].map(inflation_by_year)
df['growth_by_year'] = df['academicYear'].map(growth_by_year)

# Save the updated DataFrame to a new CSV file
df.to_csv('updated_final_tuik.csv', index=False)

# Display the updated DataFrame
df.head()
# Out:
#    academicYear           universityName universityType  \
# 0          2024  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 1          2023  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 2          2022  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 3          2021  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 4          2020  İBN HALDUN ÜNİVERSİTESİ          vakıf
#
#                      faculty departmentName     idOSYM programType   language  \
# 0  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 1  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 2  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 3  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 4  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
#
#    scholarshipRate  quota  ...  totalStudentNumber  Urap_Rank  Urap_Score  \
# 0            100.0      8  ...               861.0      112.0  492.920000
# 1            100.0      8  ...               861.0      123.0  494.510000
# 2            100.0     10  ...               861.0      145.0  392.554937
# 3            100.0     10  ...               861.0      148.0  266.210000
# 4            100.0     10  ...               861.0      136.0  260.440000
#
#    normalized_department         normalized_faculty Estimated Fee  \
# 0               i̇şletme  yönetimbilimlerifakültesi           0.0
# 1               i̇şletme  yönetimbilimlerifakültesi           0.0
# 2               i̇şletme  yönetimbilimlerifakültesi           0.0
# 3               i̇şletme  yönetimbilimlerifakültesi           0.0
# 4               i̇şletme  yönetimbilimlerifakültesi           0.0
#
#    avg_monthly_income_group  base_salary_by_year  inflation_by_year  \
# 0                       0.0                17002               64.0
# 1                       0.0                11402               64.0
# 2                       0.0                 5500               64.0
# 3                       0.0                 2825               36.0
# 4                       0.0                 2103               14.0
#
#    growth_by_year
# 0             2.7
# 1             3.8
# 2             5.4
# 3            11.6
# 4             1.8
#
# [5 rows x 50 columns]

# %%
# Copy the values from 'Estimated Fee' to 'tuitionFee'
df['tuitionFee'] = df['Estimated Fee']

# Drop the 'Estimated Fee' column
df.drop(columns=['Estimated Fee'], inplace=True)

# Display the updated DataFrame
# df.head()
print(df.isnull().sum())
# Out:
# academicYear                       0
# universityName                     0
# universityType                     0
# faculty                            0
# departmentName                     0
# idOSYM                             0
# programType                        0
# language                           0
# scholarshipRate                31241
# quota                              0
# occupiedSlots                      0
# tuitionFee                     10152
# universityFoundingYear         65281
# facultyFoundingYear            65281
# universityLocation                 0
# universityRegion                   0
# profCount                          0
# assoCount                          0
# docCount                           0
# baseRanking                        0
# topRanking                         0
# avgAdmissionRanking(TYT)           0
# baseAdmissionRanking(TYT)          0
# stdDeviationStudents               0
# revenue                        65281
# outOfCityStudentRate               0
# totalPreference                    0
# top1PreferenceRatio                0
# avgOrderofPreference               0
# tuitionFeeIncrease             65281
# avgAdmittedStudentPrefOrder        0
# top1AdmittedRatio                  0
# top3AdmittedRatio                  0
# top10AdmittedRatio                 0
# admittedTotalPref                  0
# admittedTotalDepartmentPref        0
# currentStudentCount                0
# baseScore                         33
# topScore                          31
# totalForeignStudents             295
# totalStudentNumber               295
# Urap_Rank                       3579
# Urap_Score                      3579
# normalized_department              0
# normalized_faculty                 0
# avg_monthly_income_group        7375
# dtype: int64

# %%
# Calculate revenue for 'vakıf' university types
df.loc[df['universityType'] == 'vakıf', 'revenue'] = df['tuitionFee'] * df['occupiedSlots']

# Find and drop columns with all empty values
empty_columns = df.columns[df.isnull().all()]
df.drop(columns=empty_columns, inplace=True)
df.drop(columns=['normalized_faculty','normalized_department'], inplace=True)

# Calculate the tuition fee increase compared to the previous year
df.sort_values(by=['universityName', 'departmentName', 'academicYear'], inplace=True)

# Display the updated DataFrame
df.head()
# Out:
#        academicYear             universityName universityType  \
# 17649          2019  ABDULLAH GÜL ÜNİVERSİTESİ         devlet
# 17648          2020  ABDULLAH GÜL ÜNİVERSİTESİ         devlet
# 17647          2021  ABDULLAH GÜL ÜNİVERSİTESİ         devlet
# 17646          2022  ABDULLAH GÜL ÜNİVERSİTESİ         devlet
# 17645          2023  ABDULLAH GÜL ÜNİVERSİTESİ         devlet
#
#                     faculty          departmentName     idOSYM programType  \
# 17649  mühendislikfakültesi  bilgisayarmühendisliği  106510077         SAY
# 17648  mühendislikfakültesi  bilgisayarmühendisliği  106510077         SAY
# 17647  mühendislikfakültesi  bilgisayarmühendisliği  106510077         SAY
# 17646  mühendislikfakültesi  bilgisayarmühendisliği  106510077         SAY
# 17645  mühendislikfakültesi  bilgisayarmühendisliği  106510077         SAY
#
#         language  scholarshipRate  quota  ...  admittedTotalPref  \
# 17649  İngilizce              NaN     62  ...                888
# 17648  İngilizce              NaN     72  ...               1005
# 17647  İngilizce              NaN     70  ...               1044
# 17646  İngilizce              NaN     75  ...               1017
# 17645  İngilizce              NaN     75  ...               1156
#
#        admittedTotalDepartmentPref currentStudentCount     baseScore  \
# 17649                          393                 228  4.931221e+06
# 17648                          536                 228  2.339497e+02
# 17647                          622                 243  3.979366e+02
# 17646                          696                 362  4.694266e+02
# 17645                          602                 383  4.715531e+02
#
#         topScore  totalForeignStudents  totalStudentNumber  Urap_Rank  \
# 17649  518.21984                 235.0              2670.0       26.0
# 17648  279.88569                 235.0              2670.0       36.0
# 17647  444.40481                 235.0              2670.0       40.0
# 17646  513.57950                 235.0              2670.0       43.0
# 17645  507.97368                 235.0              2670.0       50.0
#
#        Urap_Score  avg_monthly_income_group
# 17649  551.940000                       2.0
# 17648  521.630000                       2.0
# 17647  506.880000                       2.0
# 17646  716.794001                       2.0
# 17645  705.460000                       2.0
#
# [5 rows x 41 columns]

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  academicYear                       0
# universityName                     0
# universityType                     0
# faculty                            0
# departmentName                     0
# idOSYM                             0
# programType                        0
# language                           0
# scholarshipRate                31241
# quota                              0
# occupiedSlots                      0
# tuitionFee                     10152
# universityLocation                 0
# universityRegion                   0
# profCount                          0
# assoCount                          0
# docCount                           0
# baseRanking                        0
# topRanking                         0
# avgAdmissionRanking(TYT)           0
# baseAdmissionRanking(TYT)          0
# stdDeviationStudents               0
# revenue                        41991
# outOfCityStudentRate               0
# totalPreference                    0
# top1PreferenceRatio                0
# avgOrderofPreference               0
# avgAdmittedStudentPrefOrder        0
# top1AdmittedRatio                  0
# top3AdmittedRatio                  0
# top10AdmittedRatio                 0
# admittedTotalPref                  0
# admittedTotalDepartmentPref        0
# currentStudentCount                0
# baseScore                         33
# topScore                          31
# totalForeignStudents             295
# totalStudentNumber               295
# Urap_Rank                       3579
# Urap_Score                      3579
# avg_monthly_income_group        7375
# dtype: int64

# %%
# Fill missing values in the baseRanking column with the mean
df['baseRanking'] = df['baseRanking'].fillna(
    df.groupby('universityName')['baseRanking'].transform('mean')
)
df['baseRanking'].isnull().sum()
print("Missing values in baseRanking column after filling with university name:", df['baseRanking'].isnull().sum())
# Out:
# Missing values in baseRanking column after filling with university name: 0

# %%
# Fill missing values in the profCount column with the mean
df['profCount'] = df['profCount'].fillna(
    df.groupby('universityName')['profCount'].transform('mean')
)

# Fill missing values in the assoCount column with the mean
df['assoCount'] = df['assoCount'].fillna(
    df.groupby('universityName')['assoCount'].transform('mean')
)

# Fill missing values in the docCount column with the mean
df['docCount'] = df['docCount'].fillna(
    df.groupby('universityName')['docCount'].transform('mean')
)

df['profCount'].isnull().sum()
print("Missing values in baseRanking column after filling with university name:", df['docCount'].isnull().sum())

# Check for missing values in each column
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in baseRanking column after filling with university name: 0
# Missing values in each column:
#  academicYear                            0
# universityName                          0
# universityType                          0
# faculty                                 0
# departmentName                          0
# idOSYM                                  0
# programType                             0
# language                                0
# scholarshipRate                     16268
# quota                                   0
# occupiedSlots                           0
# tuitionFee                              0
# universityLocation                      0
# universityRegion                        0
# profCount                               0
# assoCount                               0
# docCount                                0
# baseRanking                             0
# topRanking                            213
# avgAdmissionRanking(TYT)             3834
# baseAdmissionRanking(TYT)             527
# stdDeviationStudents                 1624
# revenue                             16569
# outOfCityStudentRate                    0
# sameRegionStudentRate                   0
# totalPreference                         0
# top1PreferenceRatio                     0
# top3PreferenceRatio                     0
# top9PreferenceRatio                     0
# avgOrderofPreference                   49
# avgAdmittedStudentPrefOrder           527
# top1AdmittedRatio                       0
# top3AdmittedRatio                       0
# top10AdmittedRatio                      0
# admittedGovPref                       754
# admittedPrivPref                      527
# admittedTotalPref                     527
# admittedTotalDepartmentPref           527
# currentStudentCount                  1326
# totalForeignStudents                   88
# totalStudentNumber                     88
# Urap_Rank                            1483
# Urap_Score                           1483
# avg_monthly_income_group             8195
# Time for Graduates to Find a Job     8195
# employment_rate                      8195
# base_salary_by_year                     0
# inflation_by_year                       0
# growth_by_year                          0
# dtype: int64

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  academicYear                       0
# universityName                     0
# universityType                     0
# faculty                            0
# departmentName                     0
# idOSYM                             0
# programType                        0
# language                           0
# scholarshipRate                31241
# quota                              0
# occupiedSlots                      0
# tuitionFee                     10152
# universityLocation                 0
# universityRegion                   0
# profCount                          0
# assoCount                          0
# docCount                           0
# baseRanking                        0
# topRanking                         0
# avgAdmissionRanking(TYT)           0
# baseAdmissionRanking(TYT)          0
# stdDeviationStudents               0
# revenue                        41991
# outOfCityStudentRate               0
# totalPreference                    0
# top1PreferenceRatio                0
# avgOrderofPreference               0
# avgAdmittedStudentPrefOrder        0
# top1AdmittedRatio                  0
# top3AdmittedRatio                  0
# top10AdmittedRatio                 0
# admittedTotalPref                  0
# admittedTotalDepartmentPref        0
# currentStudentCount                0
# baseScore                         33
# topScore                          31
# totalForeignStudents             295
# totalStudentNumber               295
# Urap_Rank                       3579
# Urap_Score                      3579
# avg_monthly_income_group        7375
# dtype: int64

# %%
# Fill missing values in the topRanking column with the mean
df['topRanking'] = df['topRanking'].fillna(
    df.groupby('universityName')['topRanking'].transform('mean')
)
df['avgAdmissionRanking'] = pd.to_numeric(df['avgAdmissionRanking(TYT)'], errors='coerce')
df['baseAdmissionRanking'] = pd.to_numeric(df['baseAdmissionRanking(TYT)'], errors='coerce')
# Fill missing values in the avgAdmissionRanking column with the mean
df['avgAdmissionRanking'] = df['avgAdmissionRanking'].fillna(
    df.groupby('universityName')['avgAdmissionRanking'].transform('mean')
)
df['baseAdmissionRanking'] = df['baseAdmissionRanking'].fillna(
    df.groupby('universityName')['baseAdmissionRanking'].transform('mean')
)
df['stdDeviationStudents'] = df['stdDeviationStudents'].fillna(
    df.groupby('universityName')['stdDeviationStudents'].transform('mean')
)

df.drop(columns=['avgAdmissionRanking(TYT)', 'baseAdmissionRanking(TYT)'], inplace=True)

# Check for missing values in each column
df.fillna(0, inplace=True)

# ScholarshipRate and revenue columns have missing values devlet university types
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  academicYear                        0
# universityName                      0
# universityType                      0
# faculty                             0
# departmentName                      0
# idOSYM                              0
# programType                         0
# language                            0
# scholarshipRate                     0
# quota                               0
# occupiedSlots                       0
# tuitionFee                          0
# universityLocation                  0
# universityRegion                    0
# profCount                           0
# assoCount                           0
# docCount                            0
# baseRanking                         0
# topRanking                          0
# stdDeviationStudents                0
# revenue                             0
# outOfCityStudentRate                0
# sameRegionStudentRate               0
# totalPreference                     0
# top1PreferenceRatio                 0
# top3PreferenceRatio                 0
# top9PreferenceRatio                 0
# avgOrderofPreference                0
# avgAdmittedStudentPrefOrder         0
# top1AdmittedRatio                   0
# top3AdmittedRatio                   0
# top10AdmittedRatio                  0
# admittedGovPref                     0
# admittedPrivPref                    0
# admittedTotalPref                   0
# admittedTotalDepartmentPref         0
# currentStudentCount                 0
# totalForeignStudents                0
# totalStudentNumber                  0
# Urap_Rank                           0
# Urap_Score                          0
# avg_monthly_income_group            0
# Time for Graduates to Find a Job    0
# employment_rate                     0
# base_salary_by_year                 0
# inflation_by_year                   0
# growth_by_year                      0
# avgAdmissionRanking                 0
# baseAdmissionRanking                0
# dtype: int64

# %% [markdown]
# Missing values imputated

# %%
non_numeric_columns = df.select_dtypes(exclude=['number']).columns

print("Non-numeric columns before conversion:", non_numeric_columns)
# Out:
# Non-numeric columns before conversion: Index(['universityName', 'universityType', 'faculty', 'departmentName',
#        'programType', 'language', 'universityLocation', 'universityRegion',
#        'outOfCityStudentRate', 'sameRegionStudentRate', 'top1AdmittedRatio',
#        'top3AdmittedRatio', 'top10AdmittedRatio',
#        'Time for Graduates to Find a Job', 'employment_rate'],
#       dtype='object')

# %%
# Convert percentage columns to float
percentage_columns = ['top1AdmittedRatio', 'top3AdmittedRatio', 'top10AdmittedRatio']

for col in percentage_columns:
    df[col] = df[col].str.replace('%', '').str.replace(',', '.').astype(float) / 100

print("Non-numeric columns after conversion:", df.select_dtypes(exclude=['number']).columns)
# Out:
# Non-numeric columns after conversion: Index(['universityName', 'universityType', 'faculty', 'departmentName',
#        'programType', 'language', 'universityLocation', 'universityRegion',
#        'outOfCityStudentRate', 'sameRegionStudentRate',
#        'Time for Graduates to Find a Job', 'employment_rate'],
#       dtype='object')

# %%
# Convert dot columns to float UNKNOWNS to NaN values
dot_columns = ['sameRegionStudentRate', 'outOfCityStudentRate', 'Time for Graduates to Find a Job', 'employment_rate']

for col in dot_columns:
    df[col] = pd.to_numeric(df[col].str.replace(',', '.'), errors='coerce')

# %%
print("Non-numeric columns after conversion:", df.select_dtypes(exclude=['number']).columns)
# Out:
# Non-numeric columns after conversion: Index(['universityName', 'universityType', 'faculty', 'departmentName',
#        'programType', 'language', 'universityLocation', 'universityRegion'],
#       dtype='object')

# %%
print(df.isnull().sum())
df.rename(columns={'Time for Graduates to Find a Job': 'Time_for_employment'}, inplace=True)
# Out:
# academicYear                           0
# universityName                         0
# universityType                         0
# faculty                                0
# departmentName                         0
# idOSYM                                 0
# programType                            0
# language                               0
# scholarshipRate                        0
# quota                                  0
# occupiedSlots                          0
# tuitionFee                             0
# universityLocation                     0
# universityRegion                       0
# profCount                              0
# assoCount                              0
# docCount                               0
# baseRanking                            0
# topRanking                             0
# stdDeviationStudents                   0
# revenue                                0
# outOfCityStudentRate                 182
# sameRegionStudentRate                182
# totalPreference                        0
# top1PreferenceRatio                    0
# top3PreferenceRatio                    0
# top9PreferenceRatio                    0
# avgOrderofPreference                   0
# avgAdmittedStudentPrefOrder            0
# top1AdmittedRatio                      0
# top3AdmittedRatio                      0
# top10AdmittedRatio                     0
# admittedGovPref                        0
# admittedPrivPref                       0
# admittedTotalPref                      0
# admittedTotalDepartmentPref            0
# currentStudentCount                    0
# totalForeignStudents                   0
# totalStudentNumber                     0
# Urap_Rank                              0
# Urap_Score                             0
# avg_monthly_income_group               0
# Time for Graduates to Find a Job    8272
# employment_rate                     8272
# base_salary_by_year                    0
# inflation_by_year                      0
# growth_by_year                         0
# avgAdmissionRanking                    0
# baseAdmissionRanking                   0
# dtype: int64

# %%
df.fillna(0, inplace=True)
print(df.isnull().sum())
df.to_csv('final_dataset.csv', index=False)
# Out:
# academicYear                   0
# universityName                 0
# universityType                 0
# faculty                        0
# departmentName                 0
# idOSYM                         0
# programType                    0
# language                       0
# scholarshipRate                0
# quota                          0
# occupiedSlots                  0
# tuitionFee                     0
# universityLocation             0
# universityRegion               0
# profCount                      0
# assoCount                      0
# docCount                       0
# baseRanking                    0
# topRanking                     0
# stdDeviationStudents           0
# revenue                        0
# outOfCityStudentRate           0
# sameRegionStudentRate          0
# totalPreference                0
# top1PreferenceRatio            0
# top3PreferenceRatio            0
# top9PreferenceRatio            0
# avgOrderofPreference           0
# avgAdmittedStudentPrefOrder    0
# top1AdmittedRatio              0
# top3AdmittedRatio              0
# top10AdmittedRatio             0
# admittedGovPref                0
# admittedPrivPref               0
# admittedTotalPref              0
# admittedTotalDepartmentPref    0
# currentStudentCount            0
# totalForeignStudents           0
# totalStudentNumber             0
# Urap_Rank                      0
# Urap_Score                     0
# avg_monthly_income_group       0
# Time_for_employment            0
# employment_rate                0
# base_salary_by_year            0
# inflation_by_year              0
# growth_by_year                 0
# avgAdmissionRanking            0
# baseAdmissionRanking           0
# dtype: int64
