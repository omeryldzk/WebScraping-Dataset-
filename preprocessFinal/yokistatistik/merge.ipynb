# %%
import pandas as pd
import numpy as np

# Load the dataset, ensuring "ucret" is read as a string
df = pd.read_csv('2019-2024.csv')

print(df.isnull().sum())

# Convert "baseRanking" and "topRanking" columns to numeric, forcing errors to NaN
df["baseRanking"] = pd.to_numeric(df["baseRanking"], errors='coerce')
df["topRanking"] = pd.to_numeric(df["topRanking"], errors='coerce')

# Function to calculate standard deviation for baseRanking and topRanking
def calculate_std(row):
    values = [row["baseRanking"], row["topRanking"]]
    return np.std(values)

# Apply the function to each row
df["stdDeviationStudents"] = df.apply(calculate_std, axis=1)

# Save updated DataFrame to a new CSV
df.to_csv("updated_data.csv", index=False)

# print(df.describe().round(3))
# Out:
# /var/folders/lz/72v2qwyx34g0fk80lsqg3qt80000gn/T/ipykernel_62775/2444210780.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('2019-2024.csv')
# academicYear                       0
# universityName                     0
# universityType                     0
# faculty                            0
# departmentName                     0
# idOSYM                             0
# programType                        0
# language                           0
# scholarshipRate                30874
# quota                              0
# occupiedSlots                      0
# tuitionFee                     65281
# universityFoundingYear         65281
# facultyFoundingYear            65281
# universityLocation                 0
# universityRegion                   0
# profCount                          0
# assoCount                          0
# docCount                           0
# baseRanking                        0
# topRanking                         0
# avgAdmissionRanking(TYT)           0
# baseAdmissionRanking(TYT)          0
# stdDeviationStudents           65281
# revenue                        65281
# outOfCityStudentRate               0
# totalPreference                    0
# top1PreferenceRatio                0
# avgOrderofPreference               0
# tuitionFeeIncrease             65281
# avgAdmittedStudentPrefOrder        0
# top1AdmittedRatio                  0
# top3AdmittedRatio                  0
# top10AdmittedRatio                 0
# admittedTotalPref                  0
# admittedTotalDepartmentPref        0
# currentStudentCount                0
# baseScore                         33
# topScore                          31
# dtype: int64

# %%
import pandas as pd

# Load the DataFrames from the CSV files
df = pd.read_csv('updated_data.csv')
df2 = pd.read_csv('foreignStudentDataFinal.csv')

# Create lookup dictionaries
foreign_students_lookup = df2.set_index('universityName')['totalForeignStudents'].to_dict()
total_students_lookup = df2.set_index('universityName')['totalStudentNumber'].to_dict()

# Add new columns to df based on the lookup dictionaries
df['totalForeignStudents'] = df['universityName'].map(foreign_students_lookup)
df['totalStudentNumber'] = df['universityName'].map(total_students_lookup)

# Save the updated DataFrame to a new CSV file
df.to_csv("updated_data.csv", index=False)

# Display the updated DataFrame
print(df.describe().round(3))
# Out:
# /var/folders/lz/72v2qwyx34g0fk80lsqg3qt80000gn/T/ipykernel_62775/3199410237.py:4: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('updated_data.csv')
#        academicYear        idOSYM      quota  occupiedSlots  tuitionFee  \
# count     65281.000  6.528100e+04  65281.000      65281.000         0.0
# mean       2021.387  1.561391e+08     42.189         39.478         NaN
# std           1.657  4.918308e+07     79.055         75.091         NaN
# min        2019.000  1.001100e+08      1.000          1.000         NaN
# 25%        2020.000  1.059901e+08     10.000          8.000         NaN
# 50%        2021.000  2.002117e+08     31.000         29.000         NaN
# 75%        2023.000  2.035109e+08     60.000         60.000         NaN
# max        2024.000  2.104028e+08   5800.000       5945.000         NaN
#
#        universityFoundingYear  facultyFoundingYear  profCount  assoCount  \
# count                     0.0                  0.0  65281.000  65281.000
# mean                      NaN                  NaN      4.437      2.272
# std                       NaN                  NaN     16.776      6.209
# min                       NaN                  NaN      0.000      0.000
# 25%                       NaN                  NaN      0.000      0.000
# 50%                       NaN                  NaN      1.000      1.000
# 75%                       NaN                  NaN      3.000      2.000
# max                       NaN                  NaN    321.000    106.000
#
#         docCount  ...  avgOrderofPreference  tuitionFeeIncrease  \
# count  65281.000  ...             65281.000                 0.0
# mean       4.604  ...                 8.931                 NaN
# std        7.903  ...                 2.013                 NaN
# min        0.000  ...                 1.000                 NaN
# 25%        2.000  ...                 7.600                 NaN
# 50%        3.000  ...                 8.900                 NaN
# 75%        5.000  ...                10.200                 NaN
# max      110.000  ...                24.000                 NaN
#
#        avgAdmittedStudentPrefOrder  admittedTotalPref  \
# count                    65281.000          65281.000
# mean                         5.753            527.860
# std                          2.642            900.595
# min                          0.000              1.000
# 25%                          3.800            109.000
# 50%                          5.500            340.000
# 75%                          7.300            775.000
# max                         24.000          83518.000
#
#        admittedTotalDepartmentPref  currentStudentCount     baseScore  \
# count                    65281.000            65281.000  6.524800e+04
# mean                       231.177              276.253  1.150593e+12
# std                        372.719             4266.494  9.850208e+13
# min                          0.000                0.000  0.000000e+00
# 25%                         38.000               33.000  2.545750e+02
# 50%                        107.000               97.000  3.095460e+02
# 75%                        286.000              240.000  3.824490e+02
# max                       6871.000           632209.000  9.139548e+15
#
#            topScore  totalForeignStudents  totalStudentNumber
# count  6.525000e+04             64986.000           64986.000
# mean   1.166040e+11              1834.778           13950.991
# std    2.978537e+13              2168.747            9855.796
# min    0.000000e+00                 2.000               0.000
# 25%    3.112180e+02               392.000            6359.000
# 50%    3.640950e+02              1093.000           12278.000
# 75%    4.274220e+02              2210.000           19243.000
# max    7.608399e+15             15755.000           43610.000
#
# [8 rows x 29 columns]

# %%
print(df.isnull().sum())
# Out:
# academicYear                       0
# universityName                     0
# universityType                     0
# faculty                            0
# departmentName                     0
# idOSYM                             0
# programType                        0
# language                           0
# scholarshipRate                30874
# quota                              0
# occupiedSlots                      0
# tuitionFee                     65281
# universityFoundingYear         65281
# facultyFoundingYear            65281
# universityLocation                 0
# universityRegion                   0
# profCount                          0
# assoCount                          0
# docCount                           0
# baseRanking                        0
# topRanking                         0
# avgAdmissionRanking(TYT)           0
# baseAdmissionRanking(TYT)          0
# stdDeviationStudents               0
# revenue                        65281
# outOfCityStudentRate               0
# totalPreference                    0
# top1PreferenceRatio                0
# avgOrderofPreference               0
# tuitionFeeIncrease             65281
# avgAdmittedStudentPrefOrder        0
# top1AdmittedRatio                  0
# top3AdmittedRatio                  0
# top10AdmittedRatio                 0
# admittedTotalPref                  0
# admittedTotalDepartmentPref        0
# currentStudentCount                0
# baseScore                         33
# topScore                          31
# totalForeignStudents             295
# totalStudentNumber               295
# dtype: int64
